# %% [markdown]
# ### Step 1 : Include Libraries and Initialize Spark Session

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.0.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0 pyspark-shell'

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql import functions as F
from pyspark.sql.types import *

spark = SparkSession \
    .builder \
    .appName("Log Analysis in Spark") \
    .getOrCreate()

# %% [markdown]
# ## Use-Case : Tracking Server Access Log <a class="anchor" name="use-case"></a>
# For this case, a server is going to continuously send a records of a host who is trying to access some endpoint (url) from the web server. This data will be send from a kafka producer (<code>2.Lab-Task-KafkaProducer.ipynb</code>) which is reading the data from a txt file in the dataset provided (<code>logs/access_log.txt</code>).
#
# Each line contains some valuable information such as:
#
# 1. Host
# 2. Timestamp
# 3. HTTP method
# 4. URL endpoint
# 5. Status code
# 6. Protocol
# 7. Content Size
#
# The goal here is to perform some real time queries from this stream of data and be able to output the results in multiple ways.

# %% [markdown]
# ### Step 2 : Load Kafka Stream
# Use the <code>readStream</code> to load data from the Kafka Producer <strong>2.Lab-Task-KafkaProducer.ipynb</strong>

# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">1. Lab Task: </strong>
#     Write the code below to readStream from the the producer into <code>df_urls</code> dataframe.
# </div>

# %%
# Monitor the logs data stream for new log data
topic = "w10_access_log"

hostip = "10.192.90.63"
df_urls = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", f'{hostip}:9092') \
    .option("subscribe", topic) \
    .load()

# %% [markdown]
# ## Data Preparation <a class="anchor" name="data-prep"></a>
# We need to convert the data from the message in order to perform some queries. The steps to parse the data are:
#
# 1. Get message as a string from <code>value</code> which is binary.
# 2. Implement some regular expressions to capture specific fields in the message which is a line from the access log.
# 3. Extract the values using the regular expressions to create the dataframe.

# %%
# Get value of the kafka message
log_lines = df_urls.selectExpr("CAST(value AS STRING)")

# Parse out the common log format to a DataFrame
statusExp = r'\s(\d{3})\s'
generalExp = r'\"(\S+)\s(\S+)\s*(\S*)\"'
hostExp = r'(^\S+\.[\S+\.]+\S+)\s'

df_logs = log_lines.select(regexp_extract('value', hostExp, 1).alias('host'),
                         regexp_extract('value', generalExp, 1).alias('method'),
                         regexp_extract('value', generalExp, 2).alias('endpoint'),
                         regexp_extract('value', generalExp, 3).alias('protocol'),
                         regexp_extract('value', statusExp, 1).cast('integer').alias('status'))

df_logs.printSchema()
# Out:
# root
#  |-- host: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- endpoint: string (nullable = true)
#  |-- protocol: string (nullable = true)
#  |-- status: integer (nullable = true)

# %% [markdown]
# ## Data Streaming Processing

# %% [markdown]
# <a class="anchor" id="lab-task-2"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">2. Lab Task: </strong>
#     Write a DataFrame query to filter out those requests that were not successful using <code>status !=200</code> filter.
# </div>

# %%
# 1. DF that filters those requests that were not successful (status != 200)
unsuccess_df = df_logs.filter(F.col("status") != 200) #WRITE THE CODE HERE

# %% [markdown]
# <a class="anchor" id="lab-task-3"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">3. Lab Task: </strong>
#     Write a DataFrame query count the number of requests by access status code
# </div>

# %%
# 2. DF that keeps a running count of every access by status code
status_count_df = df_logs.groupBy('status').count()

# %% [markdown]
# ## Output sink <a class="anchor" name="output-sink"></a>
# Before starting this section, run the kafka producer (<code>2.Lab-Task-KafkaProducer.ipynb</code>) that will send the data from the access log file.

# %%
# Create function to show values received from input dataframe
def foreach_batch_function(df, epoch_id):
    df.show(20,False)

# %% [markdown]
# #### Display stream output in notebook <a class="anchor" name="foreachBatch"></a>

# %%
# Write output of status_count_df in output cell using the foreach_batch_function
# Control the amount of times output is displayed with trigger function
query1 = status_count_df.writeStream.outputMode("complete")\
        .foreachBatch(foreach_batch_function)\
        .trigger(processingTime='5 seconds')\
        .start()
# Out:
# +------+-----+
# |status|count|
# +------+-----+
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |9    |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |16   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |21   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |25   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |29   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |33   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |38   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |43   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |48   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |53   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |58   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |62   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |67   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |72   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |77   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |84   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |87   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |92   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |97   |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |102  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |107  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |112  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |117  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |122  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |127  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |132  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |137  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |141  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |146  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |151  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |156  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |161  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |166  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |171  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |176  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |181  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |186  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |191  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |196  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |201  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |206  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |211  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |216  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |221  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |226  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |231  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |237  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |241  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |246  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |251  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |256  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |261  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |266  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |271  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |276  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |281  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |286  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |291  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |296  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |301  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |306  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |311  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |316  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |200   |321  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |325  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |330  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |335  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |340  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |345  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |350  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |355  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |360  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |365  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |370  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |375  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |380  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |385  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |390  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |395  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |400  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |405  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |410  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |415  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |420  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |425  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |430  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |435  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |440  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |445  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |450  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |455  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |460  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |465  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |470  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |475  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |480  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |485  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |490  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |495  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |500  |
# +------+-----+
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |505  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |510  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |515  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |520  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |525  |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |1    |
# |200   |530  |
# +------+-----+

# %%
query1.stop()

# %% [markdown]
# <a class="anchor" id="lab-task-4"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">4. Lab Task: </strong>
#     Write the stream output (<strong>for the unsucess_df</strong>) to the <strong>memory sink</strong> and display the result using <strong>spark SQL</strong>
# </div>

# %%
#WRITE THE CODE HERE TO WRITE OUTPUT TO MEMORY SINK
assert unsuccess_df.isStreaming, "The DataFrame is not streaming!"
query2 = unsuccess_df.writeStream.format("memory")\
        .outputMode("append")\
        .foreachBatch(foreach_batch_function)\
        .queryName("unsuccess_sql")\
        .trigger(processingTime='5 seconds')\
        .start()
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[15], line 8
#       1 #WRITE THE CODE HERE TO WRITE OUTPUT TO MEMORY SINK
#       2 assert unsuccess_df.isStreaming, "The DataFrame is not streaming!"
#       3 query2 = unsuccess_df.writeStream.format("memory")\
#       4         .outputMode("append")\
#       5         .foreachBatch(foreach_batch_function)\
#       6         .queryName("unsuccess_sql")\
#       7         .trigger(processingTime='5 seconds')\
# ----> 8         .start()
#
# File /opt/conda/lib/python3.10/site-packages/pyspark/sql/streaming/readwriter.py:1527, in DataStreamWriter.start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1525     self.queryName(queryName)
#    1526 if path is None:
# -> 1527     return self._sq(self._jwrite.start())
#    1528 else:
#    1529     return self._sq(self._jwrite.start(path))
#
# File /opt/conda/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/conda/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# IllegalArgumentException: Cannot start query with name unsuccess_sql as a query with that name is already active in this SparkSession
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1007 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1012 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1017 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+

# %%
#WRITE THE CODE HERE TO QUERY THE TABLE FROM MEMORY SINK
spark.sql("Select * from unsuccess_sql").show()
# Out:
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1022 |
# +------+-----+
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 #WRITE THE CODE HERE TO QUERY THE TABLE FROM MEMORY SINK
# ----> 2 spark.sql("Select * from unsuccess_sql").show()
#
# File /opt/conda/lib/python3.10/site-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File /opt/conda/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/conda/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `unsuccess_sql` cannot be found. Verify the spelling and correctness of the schema and catalog.
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS.; line 1 pos 14;
# 'Project [*]
# +- 'UnresolvedRelation [unsuccess_sql], [], false
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1027 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1032 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1037 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1042 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1047 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1061 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1069 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1074 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1079 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1084 |
# +------+-----+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1089 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1094 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1099 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +------+-----+
# |status|count|
# +------+-----+
# |301   |2    |
# |200   |1104 |
# +------+-----+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
#
# +----+------+--------+--------+------+
# |host|method|endpoint|protocol|status|
# +----+------+--------+--------+------+
# +----+------+--------+--------+------+
