# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt
import csv

#configuration
hostip = "10.192.89.180" #change to your machine IP address
# hostip = "192.168.87.1"


def readCSVFile(fileName):
    list=[]
    with open(fileName, 'rt') as f:
        reader = csv.DictReader(f)
        for row in reader:
            list.append(row)
    return list

def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'clickstream'
    cRows = readCSVFile('data/clickstream.csv')
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    start_index=0
    #number of rows to send
    rows_to_send=random.randint(5,10)
    while True:
        
        to_send = cRows[start_index:start_index+rows_to_send]
        #increase the start index by the number of rows taken
        start_index = start_index+rows_to_send
        #append the timestamp into the object to be sent
        data = {'data':to_send,'ts': int(dt.datetime.now().timestamp())}
        publish_message(producer, topic, data)
        
        #reset to start from begining
        if(start_index>=len(cRows)):
            start_index=0
        sleep(5)
# Out:
# Publishing records..
# Message published successfully. Data: {'data': [{'Age': '36', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '73', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '49', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '11', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '46', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790727}
# Message published successfully. Data: {'data': [{'Age': '16', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '52', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '57', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790732}
# Message published successfully. Data: {'data': [{'Age': '40', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '59', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '61', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790737}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '19', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '66', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790742}
# Message published successfully. Data: {'data': [{'Age': '23', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '74', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '65', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '2', 'Signed_In': '0'}], 'ts': 1758790747}
# Message published successfully. Data: {'data': [{'Age': '32', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '61', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '35', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790752}
# Message published successfully. Data: {'data': [{'Age': '73', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '33', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '34', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790757}
# Message published successfully. Data: {'data': [{'Age': '34', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '17', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '1', 'Signed_In': '0'}], 'ts': 1758790762}
# Message published successfully. Data: {'data': [{'Age': '57', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '62', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '11', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790767}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '42', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '14', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '64', 'Gender': '1', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '24', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790772}
# Message published successfully. Data: {'data': [{'Age': '18', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '42', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790777}
# Message published successfully. Data: {'data': [{'Age': '22', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '61', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '19', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790782}
# Message published successfully. Data: {'data': [{'Age': '71', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '62', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '61', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790787}
# Message published successfully. Data: {'data': [{'Age': '32', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '49', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '31', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790792}
# Message published successfully. Data: {'data': [{'Age': '19', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '45', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '28', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790797}
# Message published successfully. Data: {'data': [{'Age': '32', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '64', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '83', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790802}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '59', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '14', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790807}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '79', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '48', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '29', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '0', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790812}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '22', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '67', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '51', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '47', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790817}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '60', 'Gender': '1', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '29', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '60', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '38', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790822}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '30', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '18', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790827}
# Message published successfully. Data: {'data': [{'Age': '18', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '38', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '25', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790832}
# Message published successfully. Data: {'data': [{'Age': '30', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '34', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '61', 'Gender': '0', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '50', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '44', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790837}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '44', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '46', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '76', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '52', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790842}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '41', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '34', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '34', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '2', 'Signed_In': '0'}, {'Age': '15', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '41', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790847}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '48', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '78', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790852}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '39', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '41', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790857}
# Message published successfully. Data: {'data': [{'Age': '23', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '41', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790862}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '48', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '50', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '25', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790867}
# Message published successfully. Data: {'data': [{'Age': '42', 'Gender': '1', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '67', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '55', 'Gender': '0', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758790872}
# Message published successfully. Data: {'data': [{'Age': '36', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '73', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790877}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '53', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '1', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '50', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790882}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '37', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '29', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790887}
# Message published successfully. Data: {'data': [{'Age': '47', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790892}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '67', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '56', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '52', 'Gender': '1', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '55', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790897}
# Message published successfully. Data: {'data': [{'Age': '77', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '64', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790902}
# Message published successfully. Data: {'data': [{'Age': '40', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '85', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '35', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '62', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '65', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '39', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790907}
# Message published successfully. Data: {'data': [{'Age': '66', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '58', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '71', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790912}
# Message published successfully. Data: {'data': [{'Age': '48', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '19', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '60', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '55', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790917}
# Message published successfully. Data: {'data': [{'Age': '23', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '82', 'Gender': '1', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '35', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '28', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '23', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790922}
# Message published successfully. Data: {'data': [{'Age': '45', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '16', 'Gender': '1', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '17', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790927}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '40', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '1', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '50', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '60', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790932}
# Message published successfully. Data: {'data': [{'Age': '16', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '18', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '13', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790937}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '45', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790942}
# Message published successfully. Data: {'data': [{'Age': '25', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '70', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '33', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '70', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790947}
# Message published successfully. Data: {'data': [{'Age': '33', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '45', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '37', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790952}
# Message published successfully. Data: {'data': [{'Age': '57', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790957}
# Message published successfully. Data: {'data': [{'Age': '85', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '46', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790962}
# Message published successfully. Data: {'data': [{'Age': '50', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '67', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '31', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '21', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '40', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790967}
# Message published successfully. Data: {'data': [{'Age': '66', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790972}
# Message published successfully. Data: {'data': [{'Age': '27', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '60', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '61', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790977}
# Message published successfully. Data: {'data': [{'Age': '51', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '59', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '84', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790982}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '49', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '10', 'Clicks': '2', 'Signed_In': '1'}, {'Age': '40', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758790987}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '16', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '50', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '22', 'Gender': '1', 'Impressions': '14', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '62', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790992}
# Message published successfully. Data: {'data': [{'Age': '46', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '27', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '62', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '53', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758790997}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '19', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '44', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '70', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '45', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791002}
# Message published successfully. Data: {'data': [{'Age': '54', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '59', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791007}
# Message published successfully. Data: {'data': [{'Age': '33', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '45', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758791012}
# Message published successfully. Data: {'data': [{'Age': '27', 'Gender': '1', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '17', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '51', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791017}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '71', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '1', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '1', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791022}
# Message published successfully. Data: {'data': [{'Age': '41', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '24', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '66', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '28', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791027}
# Message published successfully. Data: {'data': [{'Age': '13', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '61', 'Gender': '0', 'Impressions': '12', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '60', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758791032}
# Message published successfully. Data: {'data': [{'Age': '14', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '52', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '14', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '51', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '46', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758791037}
# Message published successfully. Data: {'data': [{'Age': '20', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '64', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '1', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758791042}
# Message published successfully. Data: {'data': [{'Age': '27', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '21', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '51', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '10', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758791047}
# ...
# Message published successfully. Data: {'data': [{'Age': '26', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '25', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '47', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '40', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793836}
# Message published successfully. Data: {'data': [{'Age': '19', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '14', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '82', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '29', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '15', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793841}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '39', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '46', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '67', 'Gender': '0', 'Impressions': '2', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '23', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793846}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '61', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '27', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '20', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793851}
# Message published successfully. Data: {'data': [{'Age': '43', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '45', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '60', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758793856}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793861}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '51', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '41', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793866}
# Message published successfully. Data: {'data': [{'Age': '38', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '28', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '64', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '73', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793871}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '41', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '66', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '26', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '28', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793876}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '51', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '19', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793881}
# Message published successfully. Data: {'data': [{'Age': '39', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '38', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '51', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '51', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758793886}
# Message published successfully. Data: {'data': [{'Age': '32', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '56', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '55', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '55', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758793891}
# Message published successfully. Data: {'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '39', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '34', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758793896}
# Message published successfully. Data: {'data': [{'Age': '54', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '49', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '29', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '76', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758793901}
# Message published successfully. Data: {'data': [{'Age': '43', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '14', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '74', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758793906}
# Message published successfully. Data: {'data': [{'Age': '68', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '12', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '68', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793911}
# Message published successfully. Data: {'data': [{'Age': '51', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '13', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '14', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '34', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}], 'ts': 1758793916}
# Message published successfully. Data: {'data': [{'Age': '27', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '22', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '50', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '51', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '68', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}], 'ts': 1758793921}
# Message published successfully. Data: {'data': [{'Age': '45', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '49', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '49', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '56', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '22', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '24', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793926}
# Message published successfully. Data: {'data': [{'Age': '70', 'Gender': '1', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '49', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '24', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793931}
# Message published successfully. Data: {'data': [{'Age': '20', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '15', 'Gender': '1', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '49', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '26', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '31', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}], 'ts': 1758793936}
