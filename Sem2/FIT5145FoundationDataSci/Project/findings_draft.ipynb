# %% [markdown]
# Original: Drop linkedin, twitter, youtube. Group messaging apps

# %% [markdown]
# --- Summary of Logistic Regression Model (Predicting Academic Performance) ---
#
# Call:
# glm(formula = Affects_Academic_Performance ~ Avg_Daily_Usage_Hours +
#     Sleep_Hours_Per_Night + Academic_Level + Most_Used_Platform_Grouped +
#     Age, family = "binomial", data = social_media_addiction_df_cleaned)
#
# Coefficients:
#                                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)                               23.1081     6.7248   3.436 0.000590 ***
# Avg_Daily_Usage_Hours                      1.7132     0.3736   4.586 4.52e-06 ***
# Sleep_Hours_Per_Night                     -1.4869     0.3733  -3.983 6.79e-05 ***
# Academic_LevelHigh School                 -6.1156     1.5062  -4.060 4.90e-05 ***
# Academic_LevelUndergraduate               -2.7778     0.5828  -4.767 1.87e-06 ***
# Most_Used_Platform_GroupedInstagram        2.7664     0.4369   6.332 2.41e-10 ***
# Most_Used_Platform_GroupedMessaging Apps   1.6911     0.5002   3.381 0.000723 ***
# Most_Used_Platform_GroupedSnapchat         3.0863     1.4120   2.186 0.028835 *
# Most_Used_Platform_GroupedTikTok           4.7263     0.6016   7.856 3.96e-15 ***
# Age                                       -0.9722     0.2320  -4.191 2.78e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# =======================================================
#           PREDICTING SLEEP_HOURS_PER_NIGHT
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Sleep Hours) ---
#
# Call:
# lm(formula = Sleep_Hours_Per_Night ~ Avg_Daily_Usage_Hours +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8544 -0.1668  0.1150  0.3404  1.4284
#
# Coefficients:
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.28709    0.74980  12.386  < 2e-16 ***
# Avg_Daily_Usage_Hours                    -0.76799    0.01971 -38.964  < 2e-16 ***
# Academic_LevelHigh School                -0.55048    0.17727  -3.105  0.00199 **
# Academic_LevelUndergraduate              -0.02507    0.10157  -0.247  0.80515
# Most_Used_Platform_GroupedInstagram      -0.04173    0.07059  -0.591  0.55456
# Most_Used_Platform_GroupedMessaging Apps  0.04772    0.08066   0.592  0.55427
# Most_Used_Platform_GroupedSnapchat       -0.75187    0.17936  -4.192 3.16e-05 ***
# Most_Used_Platform_GroupedTikTok         -0.34044    0.07569  -4.498 8.17e-06 ***
# Age                                       0.04263    0.03291   1.295  0.19563
# GenderMale                               -0.10068    0.06856  -1.468  0.14248
# Relationship_StatusIn Relationship        0.62652    0.13567   4.618 4.69e-06 ***
# Relationship_StatusSingle                 0.84965    0.13267   6.404 2.95e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5782 on 632 degrees of freedom
# Multiple R-squared:  0.7589,	Adjusted R-squared:  0.7547
# F-statistic: 180.9 on 11 and 632 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Sleep Hours Model Predictors ---
#                                GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours      1.103798  1        1.050618
# Academic_Level             6.113430  2        1.572430
# Most_Used_Platform_Grouped 1.568702  4        1.057895
# Age                        3.638967  1        1.907608
# Gender                     2.262627  1        1.504203
# Relationship_Status        1.224564  2        1.051951
#
# --- Confidence Intervals for Sleep Hours Model Coefficients ---
#                                                2.5 %      97.5 %
# (Intercept)                               7.81469379 10.75948501
# Avg_Daily_Usage_Hours                    -0.80669692 -0.72928611
# Academic_LevelHigh School                -0.89858915 -0.20237535
# Academic_LevelUndergraduate              -0.22451251  0.17438124
# Most_Used_Platform_GroupedInstagram      -0.18034359  0.09687611
# Most_Used_Platform_GroupedMessaging Apps -0.11066438  0.20611064
# Most_Used_Platform_GroupedSnapchat       -1.10409226 -0.39965708
# Most_Used_Platform_GroupedTikTok         -0.48907863 -0.19180388
# Age                                      -0.02198955  0.10724859
# GenderMale                               -0.23531314  0.03395553
# Relationship_StatusIn Relationship        0.36010775  0.89293103
# Relationship_StatusSingle                 0.58912396  1.11016856
# =======================================================
#           PREDICTING MENTAL_HEALTH_SCORE
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Mental Health Score) ---
#
# Call:
# lm(formula = Mental_Health_Score ~ Avg_Daily_Usage_Hours + Conflicts_Over_Social_Media +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.30036 -0.17965 -0.01786  0.16140  1.06334
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.648637   0.602812  16.006  < 2e-16 ***
# Avg_Daily_Usage_Hours                    -0.230331   0.025563  -9.010  < 2e-16 ***
# Conflicts_Over_Social_Media              -0.802980   0.035947 -22.338  < 2e-16 ***
# Academic_LevelHigh School                -0.169099   0.142452  -1.187  0.23565
# Academic_LevelUndergraduate              -0.049178   0.081777  -0.601  0.54781
# Most_Used_Platform_GroupedInstagram      -0.142492   0.057603  -2.474  0.01364 *
# Most_Used_Platform_GroupedMessaging Apps -0.033440   0.064916  -0.515  0.60665
# Most_Used_Platform_GroupedSnapchat       -0.350738   0.144421  -2.429  0.01544 *
# Most_Used_Platform_GroupedTikTok         -0.049033   0.063278  -0.775  0.43870
# Age                                       0.005445   0.026443   0.206  0.83693
# GenderMale                               -0.147688   0.055036  -2.683  0.00748 **
# Relationship_StatusIn Relationship        0.065295   0.109332   0.597  0.55058
# Relationship_StatusSingle                 0.087789   0.106702   0.823  0.41096
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4641 on 631 degrees of freedom
# Multiple R-squared:  0.8156,	Adjusted R-squared:  0.8121
# F-statistic: 232.6 on 12 and 631 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Mental Health Model Predictors ---
#                                 GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours       2.881288  1        1.697436
# Conflicts_Over_Social_Media 3.112392  1        1.764197
# Academic_Level              6.253245  2        1.581344
# Most_Used_Platform_Grouped  1.827442  4        1.078277
# Age                         3.646857  1        1.909675
# Gender                      2.262670  1        1.504217
# Relationship_Status         1.238494  2        1.054930
#
# --- Confidence Intervals for Mental Health Model Coefficients ---
#                                                2.5 %      97.5 %
# (Intercept)                               8.46487774 10.83239657
# Avg_Daily_Usage_Hours                    -0.28052876 -0.18013265
# Conflicts_Over_Social_Media              -0.87356950 -0.73238976
# Academic_LevelHigh School                -0.44883660  0.11063840
# Academic_LevelUndergraduate              -0.20976557  0.11140956
# Most_Used_Platform_GroupedInstagram      -0.25560914 -0.02937466
# Most_Used_Platform_GroupedMessaging Apps -0.16091797  0.09403892
# Most_Used_Platform_GroupedSnapchat       -0.63434219 -0.06713396
# Most_Used_Platform_GroupedTikTok         -0.17329368  0.07522759
# Age                                      -0.04648253  0.05737253
# GenderMale                               -0.25576317 -0.03961249
# Relationship_StatusIn Relationship       -0.14940476  0.27999407
# Relationship_StatusSingle                -0.12174479  0.29732278

# %% [markdown]
# Merge: Facebook, twitter, drop linkedin

# %% [markdown]
# --- Summary of Logistic Regression Model (Predicting Academic Performance) ---
# Call:
# glm(formula = Affects_Academic_Performance ~ Avg_Daily_Usage_Hours +
#     Sleep_Hours_Per_Night + Academic_Level + Most_Used_Platform_Grouped +
#     Age, family = "binomial", data = social_media_addiction_df_cleaned)
#
# Coefficients:
#                                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)                               18.4565     6.4143   2.877 0.004010 **
# Avg_Daily_Usage_Hours                      1.9639     0.3816   5.146 2.66e-07 ***
# Sleep_Hours_Per_Night                     -1.4058     0.3722  -3.777 0.000159 ***
# Academic_LevelHigh School                 -5.6875     1.4679  -3.875 0.000107 ***
# Academic_LevelUndergraduate               -2.5143     0.5526  -4.550 5.37e-06 ***
# Most_Used_Platform_GroupedInstagram        2.7948     0.4084   6.844 7.71e-12 ***
# Most_Used_Platform_GroupedMessaging Apps   1.6083     0.4774   3.369 0.000754 ***
# Most_Used_Platform_GroupedSnapchat         3.0411     1.4265   2.132 0.033022 *
# Most_Used_Platform_GroupedTikTok           4.7520     0.5821   8.164 3.25e-16 ***
# Most_Used_Platform_GroupedYouTube          1.0881     1.1228   0.969 0.332490
# Age                                       -0.8358     0.2134  -3.916 9.00e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 874.85  on 683  degrees of freedom
# Residual deviance: 313.70  on 673  degrees of freedom
# AIC: 335.7
#
# Number of Fisher Scoring iterations: 7
# =======================================================
#           PREDICTING SLEEP_HOURS_PER_NIGHT
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Sleep Hours) ---
#
# Call:
# lm(formula = Sleep_Hours_Per_Night ~ Avg_Daily_Usage_Hours +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8487 -0.1738  0.1048  0.3314  1.4345
#
# Coefficients:
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.48940    0.70104  13.536  < 2e-16 ***
# Avg_Daily_Usage_Hours                    -0.75915    0.01912 -39.711  < 2e-16 ***
# Academic_LevelHigh School                -0.55182    0.16906  -3.264  0.00115 **
# Academic_LevelUndergraduate              -0.03570    0.09601  -0.372  0.71016
# Most_Used_Platform_GroupedInstagram      -0.03995    0.06467  -0.618  0.53693
# Most_Used_Platform_GroupedMessaging Apps  0.04834    0.07590   0.637  0.52441
# Most_Used_Platform_GroupedSnapchat       -0.78086    0.17441  -4.477 8.89e-06 ***
# Most_Used_Platform_GroupedTikTok         -0.34096    0.06996  -4.873 1.37e-06 ***
# Most_Used_Platform_GroupedYouTube        -0.94039    0.19950  -4.714 2.96e-06 ***
# Age                                       0.03475    0.03061   1.135  0.25670
# GenderMale                               -0.09861    0.06369  -1.548  0.12200
# Relationship_StatusIn Relationship        0.55055    0.12646   4.354 1.55e-05 ***
# Relationship_StatusSingle                 0.75779    0.12319   6.152 1.32e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5698 on 671 degrees of freedom
# Multiple R-squared:  0.755,	Adjusted R-squared:  0.7506
# F-statistic: 172.3 on 12 and 671 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Sleep Hours Model Predictors ---
#                                GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours      1.109979  1        1.053555
# Academic_Level             5.944505  2        1.561453
# Most_Used_Platform_Grouped 1.791594  5        1.060044
# Age                        3.639474  1        1.907740
# Gender                     2.136152  1        1.461558
# Relationship_Status        1.269190  2        1.061406
#
# --- Confidence Intervals for Sleep Hours Model Coefficients ---
#                                                2.5 %      97.5 %
# (Intercept)                               8.11290093 10.86590468
# Avg_Daily_Usage_Hours                    -0.79668056 -0.72160967
# Academic_LevelHigh School                -0.88377263 -0.21987544
# Academic_LevelUndergraduate              -0.22421836  0.15282345
# Most_Used_Platform_GroupedInstagram      -0.16692614  0.08702459
# Most_Used_Platform_GroupedMessaging Apps -0.10069359  0.19737919
# Most_Used_Platform_GroupedSnapchat       -1.12331363 -0.43840015
# Most_Used_Platform_GroupedTikTok         -0.47833358 -0.20358489
# Most_Used_Platform_GroupedYouTube        -1.33210046 -0.54867974
# Age                                      -0.02535316  0.09484633
# GenderMale                               -0.22365951  0.02643815
# Relationship_StatusIn Relationship        0.30225294  0.79885299
# Relationship_StatusSingle                 0.51591467  0.99967133
#
# =======================================================
#           PREDICTING MENTAL_HEALTH_SCORE
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Mental Health Score) ---
#
# Call:
# lm(formula = Mental_Health_Score ~ Avg_Daily_Usage_Hours + Conflicts_Over_Social_Media +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.31266 -0.19089 -0.02169  0.16611  1.06221
#
# Coefficients:
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.58529    0.57375  16.706  < 2e-16 ***
# Avg_Daily_Usage_Hours                    -0.23181    0.02541  -9.123  < 2e-16 ***
# Conflicts_Over_Social_Media              -0.79812    0.03520 -22.677  < 2e-16 ***
# Academic_LevelHigh School                -0.16460    0.13829  -1.190  0.23436
# Academic_LevelUndergraduate              -0.01675    0.07867  -0.213  0.83146
# Most_Used_Platform_GroupedInstagram      -0.17677    0.05408  -3.268  0.00114 **
# Most_Used_Platform_GroupedMessaging Apps -0.06231    0.06214  -1.003  0.31634
# Most_Used_Platform_GroupedSnapchat       -0.39536    0.14306  -2.764  0.00587 **
# Most_Used_Platform_GroupedTikTok         -0.08928    0.06004  -1.487  0.13752
# Most_Used_Platform_GroupedYouTube        -0.34600    0.16307  -2.122  0.03422 *
# Age                                       0.01073    0.02505   0.428  0.66845
# GenderMale                               -0.13512    0.05206  -2.596  0.00965 **
# Relationship_StatusIn Relationship        0.01507    0.10389   0.145  0.88474
# Relationship_StatusSingle                 0.05106    0.10098   0.506  0.61330
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4657 on 670 degrees of freedom
# Multiple R-squared:  0.816,	Adjusted R-squared:  0.8124
# F-statistic: 228.6 on 13 and 670 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Mental Health Model Predictors ---
#                                 GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours       2.935523  1        1.713337
# Conflicts_Over_Social_Media 3.200839  1        1.789089
# Academic_Level              6.055721  2        1.568706
# Most_Used_Platform_Grouped  2.115466  5        1.077806
# Age                         3.647903  1        1.909948
# Gender                      2.136565  1        1.461700
# Relationship_Status         1.285762  2        1.064854
#
# --- Confidence Intervals for Mental Health Model Coefficients ---
#                                                2.5 %      97.5 %
# (Intercept)                               8.45872424 10.71185242
# Avg_Daily_Usage_Hours                    -0.28169837 -0.18191986
# Conflicts_Over_Social_Media              -0.86722828 -0.72901639
# Academic_LevelHigh School                -0.43613072  0.10692930
# Academic_LevelUndergraduate              -0.17120911  0.13771108
# Most_Used_Platform_GroupedInstagram      -0.28296230 -0.07057257
# Most_Used_Platform_GroupedMessaging Apps -0.18433121  0.05970407
# Most_Used_Platform_GroupedSnapchat       -0.67627218 -0.11445550
# Most_Used_Platform_GroupedTikTok         -0.20717092  0.02862013
# Most_Used_Platform_GroupedYouTube        -0.66618462 -0.02581518
# Age                                      -0.03844529  0.05990711
# GenderMale                               -0.23732986 -0.03290598
# Relationship_StatusIn Relationship       -0.18893197  0.21906532
# Relationship_StatusSingle                -0.14721803  0.24933021

# %% [markdown]
# group messaging apps, drop only linkedin (not brain rot). don't group anything else

# %% [markdown]
# --- Summary of Logistic Regression Model (Predicting Academic Performance) ---
#
# Call:
# glm(formula = Affects_Academic_Performance ~ Avg_Daily_Usage_Hours +
#     Sleep_Hours_Per_Night + Academic_Level + Most_Used_Platform_Grouped +
#     Age, family = "binomial", data = social_media_addiction_df_cleaned)
#
# Coefficients:
#                                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)                               19.2028     6.5250   2.943 0.003251 **
# Avg_Daily_Usage_Hours                      1.9395     0.3842   5.048 4.47e-07 ***
# Sleep_Hours_Per_Night                     -1.4278     0.3762  -3.795 0.000148 ***
# Academic_LevelHigh School                 -5.7910     1.4783  -3.917 8.96e-05 ***
# Academic_LevelUndergraduate               -2.5836     0.5659  -4.565 4.99e-06 ***
# Most_Used_Platform_GroupedInstagram        2.8961     0.4466   6.484 8.92e-11 ***
# Most_Used_Platform_GroupedMessaging Apps   1.7185     0.5146   3.340 0.000838 ***
# Most_Used_Platform_GroupedSnapchat         3.1470     1.4404   2.185 0.028905 *
# Most_Used_Platform_GroupedTikTok           4.8616     0.6151   7.903 2.72e-15 ***
# Most_Used_Platform_GroupedTwitter          0.3768     0.6317   0.597 0.550801
# Most_Used_Platform_GroupedYouTube          1.1863     1.1379   1.043 0.297139
# Age                                       -0.8620     0.2176  -3.962 7.42e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 874.85  on 683  degrees of freedom
# Residual deviance: 313.35  on 672  degrees of freedom
# AIC: 337.35
#
# Number of Fisher Scoring iterations: 7
#
#
# --- Odds Ratios for Logistic Regression Model ---
#                              (Intercept)                    Avg_Daily_Usage_Hours
#                             2.185994e+08                             6.955458e+00
#                    Sleep_Hours_Per_Night                Academic_LevelHigh School
#                             2.398431e-01                             3.054809e-03
#              Academic_LevelUndergraduate      Most_Used_Platform_GroupedInstagram
#                             7.550236e-02                             1.810319e+01
# Most_Used_Platform_GroupedMessaging Apps       Most_Used_Platform_GroupedSnapchat
#                             5.576147e+00                             2.326560e+01
#         Most_Used_Platform_GroupedTikTok        Most_Used_Platform_GroupedTwitter
#                             1.292335e+02                             1.457679e+00
#        Most_Used_Platform_GroupedYouTube                                      Age
#                             3.275071e+00                             4.222968e-01
#
# --- Variance Inflation Factors (VIF) for Predictors ---
#                                GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours      2.873818  1        1.695234
# Sleep_Hours_Per_Night      3.354189  1        1.831445
# Academic_Level             4.767335  2        1.477641
# Most_Used_Platform_Grouped 2.334741  6        1.073215
# Age                        3.911490  1        1.977749
#
# =======================================================
#           PREDICTING SLEEP_HOURS_PER_NIGHT
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Sleep Hours) ---
#
# Call:
# lm(formula = Sleep_Hours_Per_Night ~ Avg_Daily_Usage_Hours +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8468 -0.1681  0.1071  0.3296  1.4259
#
# Coefficients:
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.45760    0.70557  13.404  < 2e-16 ***
# Avg_Daily_Usage_Hours                    -0.75880    0.01915 -39.633  < 2e-16 ***
# Academic_LevelHigh School                -0.54622    0.16969  -3.219  0.00135 **
# Academic_LevelUndergraduate              -0.03265    0.09635  -0.339  0.73477
# Most_Used_Platform_GroupedInstagram      -0.05015    0.06914  -0.725  0.46848
# Most_Used_Platform_GroupedMessaging Apps  0.03875    0.07933   0.488  0.62538
# Most_Used_Platform_GroupedSnapchat       -0.79124    0.17627  -4.489 8.43e-06 ***
# Most_Used_Platform_GroupedTikTok         -0.35147    0.07437  -4.726 2.79e-06 ***
# Most_Used_Platform_GroupedTwitter        -0.04982    0.11897  -0.419  0.67554
# Most_Used_Platform_GroupedYouTube        -0.94959    0.20082  -4.728 2.76e-06 ***
# Age                                       0.03666    0.03097   1.184  0.23686
# GenderMale                               -0.10171    0.06416  -1.585  0.11334
# Relationship_StatusIn Relationship        0.55042    0.12654   4.350 1.57e-05 ***
# Relationship_StatusSingle                 0.75871    0.12328   6.154 1.30e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5701 on 670 degrees of freedom
# Multiple R-squared:  0.755,	Adjusted R-squared:  0.7503
# F-statistic: 158.8 on 13 and 670 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Sleep Hours Model Predictors ---
#                                GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours      1.112011  1        1.054519
# Academic_Level             5.987393  2        1.564262
# Most_Used_Platform_Grouped 1.881503  6        1.054084
# Age                        3.720715  1        1.928916
# Gender                     2.165051  1        1.471411
# Relationship_Status        1.273128  2        1.062229
#
# --- Confidence Intervals for Sleep Hours Model Coefficients ---
#                                                2.5 %      97.5 %
# (Intercept)                               8.07220239 10.84300323
# Avg_Daily_Usage_Hours                    -0.79639536 -0.72120935
# Academic_LevelHigh School                -0.87941442 -0.21303475
# Academic_LevelUndergraduate              -0.22183084  0.15652159
# Most_Used_Platform_GroupedInstagram      -0.18591912  0.08560996
# Most_Used_Platform_GroupedMessaging Apps -0.11701569  0.19451494
# Most_Used_Platform_GroupedSnapchat       -1.13734484 -0.44512905
# Most_Used_Platform_GroupedTikTok         -0.49750094 -0.20544132
# Most_Used_Platform_GroupedTwitter        -0.28342085  0.18378504
# Most_Used_Platform_GroupedYouTube        -1.34391034 -0.55527111
# Age                                      -0.02414168  0.09746705
# GenderMale                               -0.22768397  0.02425525
# Relationship_StatusIn Relationship        0.30196226  0.79887074
# Relationship_StatusSingle                 0.51664709  1.00077954
#
# =======================================================
#           PREDICTING MENTAL_HEALTH_SCORE
# =======================================================
#
# --- Summary of Linear Regression Model (Predicting Mental Health Score) ---
#
# Call:
# lm(formula = Mental_Health_Score ~ Avg_Daily_Usage_Hours + Conflicts_Over_Social_Media +
#     Academic_Level + Most_Used_Platform_Grouped + Age + Gender +
#     Relationship_Status, data = social_media_addiction_df_cleaned)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.37849 -0.19548 -0.01513  0.16952  1.06559
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               9.684722   0.576154  16.809   <2e-16 ***
# Avg_Daily_Usage_Hours                    -0.235065   0.025452  -9.236   <2e-16 ***
# Conflicts_Over_Social_Media              -0.794347   0.035224 -22.552   <2e-16 ***
# Academic_LevelHigh School                -0.183288   0.138571  -1.323   0.1864
# Academic_LevelUndergraduate              -0.025979   0.078762  -0.330   0.7416
# Most_Used_Platform_GroupedInstagram      -0.145056   0.057317  -2.531   0.0116 *
# Most_Used_Platform_GroupedMessaging Apps -0.030951   0.064895  -0.477   0.6336
# Most_Used_Platform_GroupedSnapchat       -0.363159   0.144200  -2.518   0.0120 *
# Most_Used_Platform_GroupedTikTok         -0.057303   0.063005  -0.909   0.3634
# Most_Used_Platform_GroupedTwitter         0.160833   0.097254   1.654   0.0986 .
# Most_Used_Platform_GroupedYouTube        -0.316017   0.163863  -1.929   0.0542 .
# Age                                       0.004674   0.025279   0.185   0.8534
# GenderMale                               -0.125176   0.052335  -2.392   0.0170 *
# Relationship_StatusIn Relationship        0.016644   0.103765   0.160   0.8726
# Relationship_StatusSingle                 0.048918   0.100857   0.485   0.6278
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4651 on 669 degrees of freedom
# Multiple R-squared:  0.8167,	Adjusted R-squared:  0.8129
# F-statistic:   213 on 14 and 669 DF,  p-value: < 2.2e-16
#
#
# --- Variance Inflation Factors (VIF) for Mental Health Model Predictors ---
#                                 GVIF Df GVIF^(1/(2*Df))
# Avg_Daily_Usage_Hours       2.953192  1        1.718485
# Conflicts_Over_Social_Media 3.214338  1        1.792858
# Academic_Level              6.099439  2        1.571529
# Most_Used_Platform_Grouped  2.230998  6        1.069157
# Age                         3.726117  1        1.930315
# Gender                      2.165138  1        1.471441
# Relationship_Status         1.290334  2        1.065800
#
# --- Confidence Intervals for Mental Health Model Coefficients ---
#                                                2.5 %       97.5 %
# (Intercept)                               8.55343364 10.816010757
# Avg_Daily_Usage_Hours                    -0.28503942 -0.185090129
# Conflicts_Over_Social_Media              -0.86350961 -0.725185169
# Academic_LevelHigh School                -0.45537368  0.088798372
# Academic_LevelUndergraduate              -0.18062886  0.128670573
# Most_Used_Platform_GroupedInstagram      -0.25759905 -0.032513139
# Most_Used_Platform_GroupedMessaging Apps -0.15837390  0.096471405
# Most_Used_Platform_GroupedSnapchat       -0.64629866 -0.080018677
# Most_Used_Platform_GroupedTikTok         -0.18101486  0.066408563
# Most_Used_Platform_GroupedTwitter        -0.03012704  0.351794024
# Most_Used_Platform_GroupedYouTube        -0.63776402  0.005730737
# Age                                      -0.04496245  0.054310560
# GenderMale                               -0.22793598 -0.022415105
# Relationship_StatusIn Relationship       -0.18710047  0.220387935
# Relationship_StatusSingle                -0.14911655  0.246952891
