# %% [markdown]
# Empathy - consider your user
# Make user personas, user mindmaps, etc
# Frame your problem statement
# Who, what, where, why
# Lotus blossom

# %% [markdown]
# TM05:
# Adrian Leong MDS C INTJ
# Mei Li MBIS S ISFP
# Shao Shen MAI S INFJ
# Zhang Chen MDS ISFP
# Wang Xi MDS C INTP
# Jia Yi MAI S INFJ

# %% [markdown]
# Next tuesday - onboarding presentation proposal (analysis and design report + presentation slides) to mentors during studio
